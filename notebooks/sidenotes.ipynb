# %% [markdown]
# # SNR calculation

# %% [markdown]
# ##### It appears that the SNR starts to go down at coarser resolution because the sampling is too coarse. However, it is also important to note that background division is not as straightforward at coarse resolution. For example, right now at 350 GHz, what I was doing for finer resolution appears like:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### The other option is to instead use the background calculation from the unapodized interferograms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### In the picture below, the 350 GHz resolution spectrum is overlaid over the low pass filtered spectrum calculated at full 1 GHz resolution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### For background division the frequency axis need to be interpolated onto the same grid, which looks like:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from IPython.display import Video

# %%
Video("media/su8_snr_02-07-2023.mp4", embed=True, width=900)
# Out:
# <video controls  width="900" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
Video("media/bckgnd_snr_02-07-2023.mp4", embed=True, width=900)
# Out:
# <video controls  width="900" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
